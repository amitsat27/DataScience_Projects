# %% [markdown]
# Name 	:- Amit.Y.Zope
#
# Roll No.:- 323066
#
# Gr No.	:- 21810714
#
# Division:- C
#
# Batch 	:- C3
#
# Subject	:- Data Science

# %% [markdown]
# # For Assignment 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
Housinginitial = pd.read_csv('HousingPricesDataset.csv')
Housinglater = pd.read_csv('HousingDataVisual.csv')
Housinglater.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
Housinginitial.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
Housinglater.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
Housinglater.loc[:,'Overall Grade':]
# Out:
#        Overall Grade  Area of the House from Basement (in Sqft)  \
# 0                  7                                     1180.0
# 1                  7                                     2170.0
# 2                  6                                      770.0
# 3                  7                                     1050.0
# 4                  8                                     1680.0
# ...              ...                                        ...
# 21604              8                                     1530.0
# 21605              8                                     2310.0
# 21606              7                                     1020.0
# 21607              8                                     1600.0
# 21608              7                                     1020.0
#
#        Basement Area (in Sqft)  Age of House (in Years)  Latitude  Longitude  \
# 0                            0                       63   47.5112   -122.257
# ...

# %%
# bar plots of some independant variables
Housinginitial['Overall Grade'].value_counts().plot(kind='bar')
plt.show()

# %%
# plot for no of bedrooms
Housinginitial['No of Bedrooms'].value_counts().plot(kind='bar')
plt.show()

# %%
# boxplot for sale price
print(sns.boxplot(Housinginitial['Sale Price']))
plt.show()
print(sns.boxplot(Housinglater['Sale_Price']))
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# visulising categorical variables on basis of value counts
Housinginitial['Waterfront View'].value_counts().plot(kind='bar')
plt.title("Count of Houses With Waterfront view")
plt.show()
Housinginitial['No of Times Visited'].value_counts().plot(kind='bar')
plt.title('Count of No of Times Visited')
plt.show()

# %%
sns.boxplot(x = 'Waterfront View', y = 'Sale Price', data = Housinginitial)
plt.show()
sns.boxplot(x = 'Overall Grade', y = 'Sale Price', data = Housinginitial)
plt.show()
sns.boxplot(x = 'No of Times Visited', y = 'Sale Price', data = Housinginitial)
plt.show()

# %%
plt.hist(Housinglater['Flat Area (in Sqft)'],bins=100)
plt.title('Flat Area Occurence')
plt.xlabel('Flat Area (in Sqft)')
plt.ylabel('Occurence')
plt.show()

# %%
plt.hist(Housinglater['Area of the House from Basement (in Sqft)'],bins=100)
plt.xlabel('Area of the House from Basement (in Sqft)')
plt.ylabel('Occurence')
plt.show()

# %%
size = Housinginitial['No of Times Visited'].value_counts()

plt.pie(size,explode=None,labels=Housinginitial['No of Times Visited'].unique())
plt.legend(bbox_to_anchor=(1,1),loc='lower left')
plt.title('No of Times Visited')
plt.show()

# %%
# how the sale price is distributed
plt.scatter(Housinglater['Age of House (in Years)'].values,Housinglater['Sale_Price'].values)
plt.show()
plt.scatter(Housinglater['Area of the House from Basement (in Sqft)'].values,Housinglater['Sale_Price'].values)
plt.show()
plt.scatter(Housinglater['No of Times Visited'],Housinglater['Sale_Price'].values)
plt.show()
plt.scatter(Housinglater['Area of the House from Basement (in Sqft)'],Housinglater['Sale_Price'].values)
plt.show()

# %%
# Reading the test and train datasets
X_train = pd.read_csv('HDx_train.csv')
Y_train = pd.read_csv('HDy_train.csv')
X_test = pd.read_csv('HDx_test.csv')
Y_test = pd.read_csv('HDy_test.csv')

# %%
X_train.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (15126, 28)

# %%
Y_train.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
Y_train_up = Y_train['Sale_Price']

# %%
Y_train_up
# Out:
# 0         760000.0
# 1         312000.0
# 2         600000.0
# 3         190000.0
# 4         455000.0
#            ...
# 15121     559000.0
# 15122     495500.0
# 15123     261500.0
# 15124     213000.0
# 15125    1129575.0
# Name: Sale_Price, Length: 15126, dtype: float64

# %%
X_test.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
X_test.shape
# Out:
# (6483, 28)

# %%
Y_test.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
Y_test_up = Y_test['Sale_Price']
Y_test_up
# Out:
# 0        610360.0
# 1        740000.0
# 2        537500.0
# 3        520000.0
# 4       1129575.0
#           ...
# 6478     411000.0
# 6479     835000.0
# 6480     597326.0
# 6481    1129575.0
# 6482    1129575.0
# Name: Sale_Price, Length: 6483, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression(normalize=True)
# makes b0 coefficinet zero
LR.fit(X_train,Y_train_up)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
# testing generating predictions 
predictions = LR.predict(X_test)
predictions
# Out:
# array([ 550000.54013871,  645339.25748139,  612230.85487286, ...,
#        1026223.16735842,  944048.41005879, 1204608.7500112 ])

# %%
# calculating predictions
residuals = predictions - Y_test_up
residual_table = pd.DataFrame({'Residuals':residuals,'Predictions':predictions})

# %%
Y_test_up
predictions
# Out:
# array([ 550000.54013871,  645339.25748139,  612230.85487286, ...,
#        1026223.16735842,  944048.41005879, 1204608.7500112 ])

# %%
plt.scatter(Y_test_up,predictions)
plt.suptitle('Y_TEST vs Y_predictions', fontsize=20)           
plt.xlabel('Y_TEST', fontsize=18)                          
plt.ylabel('Y_predictions', fontsize=16) 
plt.show()

# %%
# since there are multiple independant variables
residual_table = residual_table.sort_values(by='Predictions')

# %%
# plotting a single line at 0 point to get distribution of data 
# line = [i for i in range()]
linex = [i for i in range(int(residual_table['Predictions'].max()))]
liney = [0 for i in range(int(residual_table['Predictions'].max()))]

# %%
plt.scatter(residual_table['Predictions'],residual_table['Residuals'],s=2)
plt.plot(linex,liney,color='red',label='Line')
plt.ylim(-400000,400000)
plt.xlabel('Residuals')
plt.ylabel('Fitted Points')
plt.title('Residual Plot')
plt.show()

# %%
# Residual plot
plt.hist(residual_table['Residuals'], color = 'green', bins = 200)
plt.xlabel('Residuals')
plt.ylabel('frequency')
plt.title('Distribution of Residuals')
plt.show()

# %%
result = pd.DataFrame({'DataCols':X_train.columns,'Coefficients':LR.coef_})
# result
plt.figure(figsize=(12,10))
plt.barh(result.DataCols,result.Coefficients,color='grey')
plt.xlabel('Coefficients')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# # For Assignment 4

# %%
# importing datasets before and after preprocessing
datachurnafter = pd.read_csv('churnpred_A5.csv')
datachurninitial = pd.read_csv('churn_prediction.csv')

# %%
datachurnafter.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
datachurninitial.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
# datachurnafte

# %%
# categorical target variable
count_churn = datachurninitial['churn'].value_counts()
count_churn
# Out:
# 0    23122
# 1     5260
# Name: churn, dtype: int64

# %%
sns.barplot(count_churn.index,count_churn.values)
plt.title('Churn Classes')
plt.xlabel('Classes')
plt.ylabel('Frequency')
plt.show()

# %%
datachurninitial.groupby(['occupation','churn']).size().plot(kind='bar')
plt.title('Churn by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.show()

# %%
datachurnafter.groupby(['gender','churn']).size().plot(kind='bar')
plt.title('Churn by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(datachurninitial['days_since_last_transaction'],bins=8)
plt.title('Days Past From Last Transaction')
plt.xlabel('days_since_last_transaction')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Amit__Zope\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Amit__Zope\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.barplot(datachurninitial['customer_nw_category'].value_counts().index,
        datachurninitial['customer_nw_category'].value_counts().values)
plt.title('Customer Net Worth  Category')
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
datachurnafter.groupby(['customer_nw_category','churn']).size().plot(kind='bar')
plt.title('Customer Net Worth  Category Grouped by Churn')
plt.ylabel("Count")
plt.show()

# %%
datachurninitial.columns.values
# Out:
# array(['customer_id', 'vintage', 'age', 'gender', 'dependents',
#        'occupation', 'city', 'customer_nw_category', 'branch_code',
#        'days_since_last_transaction', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit',
#        'previous_month_debit', 'current_month_balance',
#        'previous_month_balance', 'churn'], dtype=object)

# %%
x = datachurnafter.drop(columns = ['churn','customer_id'],axis = 1)
y = datachurnafter['churn']

# %%
from sklearn.preprocessing import StandardScaler as SS
scalar = SS()
x = scalar.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split as tts
x_train, x_test, y_train , y_test =  tts(x,y,train_size = 0.8,random_state=20,stratify=y)

# %%
x_train.shape, x_test.shape, y_train.shape , y_test.shape
# Out:
# ((22705, 23), (5677, 23), (22705,), (5677,))

# %%
from sklearn.linear_model import LogisticRegression
splitscale = SS()
splitscale.fit_transform(x_train,x_test)
# Out:
# array([[-0.40198621, -1.35568356,  0.81582248, ..., -0.13356939,
#         -0.15145817, -0.20412836],
#        [ 0.39425005, -0.56988645, -1.22575686, ..., -0.06238578,
#         -0.20350452, -0.18396064],
#        [ 1.14707778, -0.06473117, -1.22575686, ..., -0.0680899 ,
#         -0.23790096, -0.21392266],
#        ...,
#        [ 0.21751537, -0.12085954,  0.81582248, ...,  0.0687422 ,
#         -0.27382727, -0.18285668],
#        [-0.62398977, -0.73827155,  0.81582248, ...,  0.42928455,
#         -0.24292419, -0.17387441],
#        [ 0.92321385, -0.00860281, -1.22575686, ..., -0.08065413,
#         -0.06066655, -0.03028964]])

# %%
# instance of logisticregression
logisticclassifier = LogisticRegression(class_weight='balanced')
# fitting the data
logisticclassifier.fit(x_train,y_train)
# Out:
# C:\Users\Amit__Zope\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
PredictionsLRchurn = logisticclassifier.predict(x_test)
PredictionsLRchurn
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report,accuracy_score
print("For Logistic Regression")
print('Accuracy Score :',accuracy_score(y_test,PredictionsLRchurn))
print( classification_report(y_test,PredictionsLRchurn))
# Out:
# For Logistic Regression
# Accuracy Score : 0.7163995067817509
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81      4625
#            1       0.35      0.63      0.45      1052
#
#     accuracy                           0.72      5677
#    macro avg       0.63      0.68      0.63      5677
# weighted avg       0.80      0.72      0.74      5677

# %%
predictedprobalities = logisticclassifier.predict_proba(x_test)

# %%
predictedprobalities[:,1]
# Out:
# array([0.40816442, 0.55061064, 0.45413668, ..., 0.50036512, 0.38108217,
#        0.47657464])

# %% [markdown]
# # precision recall curve

# %%
from sklearn.metrics import precision_recall_curve
precpoints,recallpoints,thresholdpoints = precision_recall_curve(y_test,predictedprobalities[:,1])

# %%
plt.plot(thresholdpoints,precpoints[:-1],label='Precision')
plt.plot(thresholdpoints,recallpoints[:-1],label='Recall')
plt.xlabel("Threshold Points")
plt.ylabel('Score')
plt.legend()
plt.show()

# %%
Coeffs = logisticclassifier.coef_.reshape(-1)

# %%
x = datachurnafter.drop(columns = ['churn','customer_id'],axis = 1)

# %%
coeff_plot = pd.DataFrame({'Coefficients':Coeffs,'variables':x.columns})

# %%
plt.figure(figsize=(8,6),dpi=120)
plt.barh(coeff_plot['variables'],coeff_plot['Coefficients'])
plt.xlabel("variables")
plt.ylabel("Coefficients")
plt.show()

# %%
# AUC ROC CURVE
from sklearn.metrics import roc_curve,roc_auc_score
for i in range(2):
    FPR[i],TPR[i],thresholds = roc_curve(y_test,predictedprobalities[:,1])

# %%
plt.plot(FPR,TPR,color='green')
plt.plot([0,1],[0,1],color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.show()
roc_auc_score(y_test,predictedprobalities[:,1])
# Out:
# 0.7364757989929093
